# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Adamax # type: ignore
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization # type: ignore
from tensorflow.keras.applications import ResNet50, EfficientNetB0, DenseNet121 # type: ignore
from tensorflow.keras import regularizers # type: ignore
from tensorflow.keras.utils import plot_model  # type: ignore
from IPython.display import Image, display
import time
import os

# General settings
img_height = 64
img_width = 64
batch_size = 250

# %%
print(tf.__version__)
# Out:
# 2.9.1

# %% [markdown]
# # Importing Data

# %%
# Split training data
train_ds = tf.keras.utils.image_dataset_from_directory(
 "train",
  seed=123,
  validation_split=0.2,
  subset="training",
  image_size=(img_height, img_width),
  batch_size=batch_size,
  
  )
# Split validation data
val_ds = tf.keras.utils.image_dataset_from_directory(
    "train",
    validation_split=0.2,
    subset="validation",
    seed=123,
    batch_size=batch_size,
    image_size=(img_height, img_width)
)


# Load the validation data
test_ds = tf.keras.utils.image_dataset_from_directory(
  "test",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

print("Training Classes:")
class_names = train_ds.class_names
print(class_names)

print("Testing Classes:")
class_names = train_ds.class_names
print(class_names)
# Out:
# Found 100000 files belonging to 2 classes.
# Using 80000 files for training.
# Found 100000 files belonging to 2 classes.
# Using 20000 files for validation.
# Found 20000 files belonging to 2 classes.
# Training Classes:
# ['FAKE', 'REAL']
# Testing Classes:
# ['FAKE', 'REAL']

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau # type: ignore

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

# for stopping epoch when the model is overfitting and restoring the best weights
call_back = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 7, restore_best_weights = True)

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_data = train_ds.prefetch(buffer_size=AUTOTUNE)
validation_data = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ##### Autotune for better pipeline efficiency

# %%
# Function to plot model architecture
def plot_model_architecture(model, filename):
    plot_model(model, show_shapes=True, to_file=filename)
    display(Image(filename))

# %%
def plot_graph_loss(history):
    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Training vs Validation Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.show()
    
def plot_graph_acc(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Training vs Validation accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.show()

# %% [markdown]
# # ResNet50

# %%
# Load and create Resnet model

resnet_base = ResNet50(weights='imagenet',
                       include_top=False,
                       input_shape=(img_height, img_width, 3),
                       pooling='max')
resnet_base.trainable = True
inputs = tf.keras.Input((img_height,img_width,3),batch_size)
x = resnet_base(inputs)
x = BatchNormalization()(x)
x = Dense(128, activation='relu', kernel_regularizer = regularizers.l2(0.01))(x)
x = Dropout(rate=0.4, seed=123)(x)
outputs = Dense(1, activation='sigmoid')(x)
Resnet50 = tf.keras.Model(inputs, outputs)
Resnet50.compile(
    optimizer=Adamax(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)
plot_model_architecture(Resnet50, "Resnet64.png")
Resnet50.summary()
# Dictionary to store training and evaluation times
stats = {}
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(250, 64, 64, 3)]        0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  batch_normalization (BatchN  (250, 2048)              8192
#  ormalization)
#
#  dense (Dense)               (250, 128)                262272
#
#  dropout (Dropout)           (250, 128)                0
#
#  dense_1 (Dense)             (250, 1)                  129
#
# =================================================================
# Total params: 23,858,305
# Trainable params: 23,801,089
# Non-trainable params: 57,216
# _________________________________________________________________

# %%
# Measure training time
start_time = time.time()
Resnet_history = Resnet50.fit(
    train_data,
    validation_data=validation_data,
    epochs=100,
    callbacks=[call_back,reduce_lr],
    verbose=1
)
training_time = time.time() - start_time
print(f"Resnet50 Training Time: {training_time:.2f} seconds")
# Out:
# Epoch 1/100
# 320/320 [==============================] - 79s 219ms/step - loss: 0.9804 - accuracy: 0.9492 - precision: 0.9476 - recall: 0.9509 - val_loss: 0.3409 - val_accuracy: 0.9660 - val_precision: 0.9578 - val_recall: 0.9748 - lr: 0.0010
# Epoch 2/100
# 320/320 [==============================] - 60s 185ms/step - loss: 0.1582 - accuracy: 0.9840 - precision: 0.9845 - recall: 0.9835 - val_loss: 0.1457 - val_accuracy: 0.9649 - val_precision: 0.9550 - val_recall: 0.9757 - lr: 0.0010
# Epoch 3/100
# 320/320 [==============================] - 63s 195ms/step - loss: 0.0522 - accuracy: 0.9889 - precision: 0.9893 - recall: 0.9885 - val_loss: 0.2159 - val_accuracy: 0.9364 - val_precision: 0.9941 - val_recall: 0.8779 - lr: 0.0010
# Epoch 4/100
# 320/320 [==============================] - 65s 203ms/step - loss: 0.0390 - accuracy: 0.9886 - precision: 0.9885 - recall: 0.9887 - val_loss: 0.1153 - val_accuracy: 0.9681 - val_precision: 0.9786 - val_recall: 0.9570 - lr: 0.0010
# Epoch 5/100
# 320/320 [==============================] - 66s 205ms/step - loss: 0.0299 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.
- accuracy: 0.9999 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0907 - val_accuracy: 0.9815 - val_precision: 0.9829 - val_recall: 0.9800 - lr: 1.0000e-07
# Epoch 19/100
# 320/320 [==============================] - 64s 200ms/step - loss: 0.0022 - accuracy: 1.0000 - precision: 0.9999 - recall: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9815 - val_precision: 0.9829 - val_recall: 0.9800 - lr: 1.0000e-07
# Resnet50 Training Time: 1245.14 seconds

# %%
# Measure evaluation time
start_time = time.time()
test_loss, test_accuracy, test_precision, test_recall = Resnet50.evaluate(test_ds)
evaluation_time = time.time() - start_time

print(f"Resnet50 Evaluation Time: {evaluation_time:.2f} seconds")
# Out:
# 80/80 [==============================] - 17s 194ms/step - loss: 0.0911 - accuracy: 0.9811 - precision: 0.9825 - recall: 0.9797
# Resnet50 Evaluation Time: 17.33 seconds

# %%
# Save model and print size
Resnet50.save("Resnet5064.h5")
Resnet50_model_size = os.path.getsize("Resnet5064.h5")
print(f"Resnet Model Size: {Resnet50_model_size / (1024 * 1024):.2f} MB")

# Store the metrics and times in the dictionary
stats[Resnet50] = {
    "training_time": training_time,
    "evaluation_time": evaluation_time,
    "test_loss": test_loss,
    "test_accuracy": test_accuracy,
    "test_precision": test_precision,
    "test_recall": test_recall,
    "model_size": Resnet50_model_size / (1024 * 1024),
    "history": Resnet_history
}
# Out:
# Resnet Model Size: 273.41 MB

# %%
plot_graph_loss(Resnet_history)
plot_graph_acc(Resnet_history)

# %% [markdown]
# # Efficient Net

# %%
# Load and create EfficientNet model

EfficientNet_base = EfficientNetB0(weights='imagenet',
                       include_top=False,
                       input_shape=(img_height, img_width, 3),
                       pooling='max')
EfficientNet_base.trainable = True
inputs = tf.keras.Input((img_height,img_width,3),batch_size)
x = EfficientNet_base(inputs)
x = BatchNormalization()(x)
x = Dense(128, activation='relu', kernel_regularizer = regularizers.l2(0.01))(x)
x = Dropout(rate=0.4, seed=123)(x)
outputs = Dense(1, activation='sigmoid')(x)
EfficientNet = tf.keras.Model(inputs, outputs)
EfficientNet.compile(
    optimizer=Adamax(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)
plot_model_architecture(EfficientNet, "EfficientNet64.png")
EfficientNet.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(250, 64, 64, 3)]        0
#
#  efficientnetb0 (Functional)  (None, 1280)             4049571
#
#  batch_normalization_1 (Batc  (250, 1280)              5120
#  hNormalization)
#
#  dense_2 (Dense)             (250, 128)                163968
#
#  dropout_1 (Dropout)         (250, 128)                0
#
#  dense_3 (Dense)             (250, 1)                  129
#
# =================================================================
# Total params: 4,218,788
# Trainable params: 4,174,205
# Non-trainable params: 44,583
# _________________________________________________________________

# %%
# Measure training time
start_time = time.time()
EfficientNet_history = EfficientNet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[call_back,reduce_lr],
    verbose=1
)
training_time = time.time() - start_time
print(f"EfficientNet Training Time: {training_time:.2f} seconds")
# Out:
# Epoch 1/100
# 320/320 [==============================] - 67s 182ms/step - loss: 0.9758 - accuracy: 0.9334 - precision_1: 0.9332 - recall_1: 0.9336 - val_loss: 0.3495 - val_accuracy: 0.9525 - val_precision_1: 0.9262 - val_recall_1: 0.9833 - lr: 0.0010
# Epoch 2/100
# 320/320 [==============================] - 59s 183ms/step - loss: 0.1727 - accuracy: 0.9742 - precision_1: 0.9749 - recall_1: 0.9735 - val_loss: 0.1179 - val_accuracy: 0.9714 - val_precision_1: 0.9777 - val_recall_1: 0.9647 - lr: 0.0010
# Epoch 3/100
- accuracy: 0.9995 - precision_1: 0.9995 - recall_1: 0.9995 - val_loss: 0.0804 - val_accuracy: 0.9811 - val_precision_1: 0.9823 - val_recall_1: 0.9797 - lr: 1.0000e-06
# Epoch 27/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9996 - precision_1: 0.9995 - recall_1: 0.9997
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 320/320 [==============================] - 62s 193ms/step - loss: 0.0034 - accuracy: 0.9996 - precision_1: 0.9995 - recall_1: 0.9997 - val_loss: 0.0805 - val_accuracy: 0.9810 - val_precision_1: 0.9823 - val_recall_1: 0.9796 - lr: 1.0000e-06
# EfficientNet Training Time: 1621.42 seconds

# %%
# Measure evaluation time
start_time = time.time()
test_loss, test_accuracy, test_precision, test_recall = EfficientNet.evaluate(test_ds)
evaluation_time = time.time() - start_time
print(f"EfficientNet Evaluation Time: {evaluation_time:.2f} seconds")

print(f"EfficientNet - Test Loss: { test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")
# Out:
# 80/80 [==============================] - 7s 83ms/step - loss: 0.0795 - accuracy: 0.9819 - precision_1: 0.9805 - recall_1: 0.9834
# EfficientNet Evaluation Time: 7.06 seconds
# EfficientNet - Test Loss: 0.0795, Test Accuracy: 0.9819, Precision: 0.9805, Recall: 0.9834

# %%
# Save model and print size
EfficientNet.save("EfficientNet64.h5")
EfficientNet_model_size = os.path.getsize("EfficientNet64.h5")
print(f"EfficientNet Model Size: {EfficientNet_model_size / (1024 * 1024):.2f} MB")
# Out:
# EfficientNet Model Size: 48.84 MB

# %%
# Store the metrics and times in the dictionary
stats[EfficientNet] = {
    "training_time": training_time,
    "evaluation_time": evaluation_time,
    "test_loss": test_loss,
    "test_accuracy": test_accuracy,
    "test_precision": test_precision,
    "test_recall": test_recall,
    "model_size":EfficientNet_model_size,
    "history": EfficientNet_history
}

# %%
plot_graph_loss(EfficientNet_history)
plot_graph_acc(EfficientNet_history)

# %% [markdown]
# # DenseNet

# %%
# Load and create EfficientNet model

DenseNet_base = DenseNet121(weights='imagenet',
                       include_top=False,
                       input_shape=(img_height, img_width, 3),
                       pooling='max')
DenseNet_base.trainable = True
inputs = tf.keras.Input((img_height,img_width,3),batch_size)
x = DenseNet_base(inputs)
x = BatchNormalization()(x)
x = Dense(128, activation='relu', kernel_regularizer = regularizers.l2(0.01))(x)
x = Dropout(rate=0.4, seed=123)(x)
outputs = Dense(1, activation='sigmoid')(x)
DenseNet = tf.keras.Model(inputs, outputs)
DenseNet.compile(
    optimizer=Adamax(learning_rate=0.001),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)
plot_model_architecture(DenseNet, "DenseNet64.png")
DenseNet.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(250, 64, 64, 3)]        0
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  batch_normalization_2 (Batc  (250, 1024)              4096
#  hNormalization)
#
#  dense_4 (Dense)             (250, 128)                131200
#
#  dropout_2 (Dropout)         (250, 128)                0
#
#  dense_5 (Dense)             (250, 1)                  129
#
# =================================================================
# Total params: 7,172,929
# Trainable params: 7,087,233
# Non-trainable params: 85,696
# _________________________________________________________________

# %%
# Measure training time
start_time = time.time()
DenseNet_history = DenseNet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[call_back,reduce_lr],
    verbose=1
)
training_time = time.time() - start_time
print(f"DenseNet Training Time: {training_time:.2f} seconds")
# Out:
# Epoch 1/100
# 320/320 [==============================] - 90s 238ms/step - loss: 0.7230 - accuracy: 0.9541 - precision_2: 0.9536 - recall_2: 0.9547 - val_loss: 0.2340 - val_accuracy: 0.9715 - val_precision_2: 0.9675 - val_recall_2: 0.9758 - lr: 0.0010
# Epoch 2/100
# 320/320 [==============================] - 76s 237ms/step - loss: 0.1221 - accuracy: 0.9825 - precision_2: 0.9831 - recall_2: 0.9818 - val_loss: 0.1601 - val_accuracy: 0.9516 - val_precision_2: 0.9886 - val_recall_2: 0.9135 - lr: 0.0010
# Epoch 3/100
# 320/320 [==============================] - 77s 240ms/step - loss: 0.0491 - accuracy: 0.9883 - precision_2: 0.9883 - recall_2: 0.9883 - val_loss: 0.1661 - val_accuracy: 0.9461 - val_precision_2: 0.9076 - val_recall_2: 0.9933 - lr: 0.0010
# Epoch 4/100
# 320/320 [==============================] - 76s 236ms/step - loss: 0.0328 - accuracy: 0.9905 - precision_2: 0.9909 - recall_2: 0.9901 - val_loss: 0.0943 - val_accuracy: 0.9736 - val_precision_2: 0.9775 - val_recall_2: 0.9696 - lr: 0.0010
# Epoch 5/100
# 320/320 [==============================] - 78s 243ms/step - loss: 0.0300 - accuracy: 0.9909 - precision_2: 0.9906 - recall_2: 0.9912 - val_loss: 0.1054 - val_accuracy: 0.9676 - val_precision_2: 0.9557 - val_recall_2: 0.9806 - lr: 0.0010
# Epoch 6/100
# 320/320 [==============================] - 76s 235ms/step - loss: 0.0241 - accuracy: 0.9931 - precision_2: 0.9934 - recall_2: 0.9929 - val_loss: 0.2078 - val_accuracy: 0.9469 - val_precision_2: 0.9949 - val_recall_2: 0.8982 - lr: 0.0010
# Epoch 7/100
# 320/320 [==============================] - 76s 237ms/step - loss: 0.0205 - accuracy: 0.9942 - precision_2: 0.9944 - recall_2: 0.9940 - val_loss: 0.0823 - val_accuracy: 0.9777 - val_precision_2: 0.9864 - val_recall_2: 0.9687 - lr: 0.0010
# Epoch 8/100
# 320/320 [==============================] - 76s 236ms/step - loss: 0.0173 - accuracy: 0.9951 - precision_2: 0.9950 - recall_2: 0.9952 - val_loss: 0.1852 - val_accuracy: 0.9559 - val_precision_2: 0.9893 - val_recall_2: 0.9218 - lr: 0.0010
# Epoch 9/100
# 320/320 [==============================] - 77s 239ms/step - loss: 0.0166 - accuracy: 0.9954 - precision_2: 0.9953 - recall_2: 0.9956 - val_loss: 0.0702 - val_accuracy: 0.9814 - val_precision_2: 0.9799 - val_recall_2: 0.9829 - lr: 0.0010
# Epoch 10/100
# 320/320 [==============================] - 76s 235ms/step - loss: 0.0135 - accuracy: 0.9961 - precision_2: 0.9961 - recall_2: 0.9961 - val_loss: 0.0922 - val_accuracy: 0.9740 - val_precision_2: 0.9601 - val_recall_2: 0.9891 - lr: 0.0010
# Epoch 11/100
# 320/320 [==============================] - 78s 241ms/step - loss: 0.0122 - accuracy: 0.9967 - precision_2: 0.9969 - recall_2: 0.9966 - val_loss: 0.0863 - val_accuracy: 0.9767 - val_precision_2: 0.9855 - val_recall_2: 0.9676 - lr: 0.0010
# Epoch 12/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9970 - precision_2: 0.9971 - recall_2: 0.9970
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 320/320 [==============================] - 76s 236ms/step - loss: 0.0111 - accuracy: 0.9970 - precision_2: 0.9971 - recall_2: 0.9970 - val_loss: 0.0832 - val_accuracy: 0.9782 - val_precision_2: 0.9722 - val_recall_2: 0.9845 - lr: 0.0010
# Epoch 13/100
# 320/320 [==============================] - 77s 239ms/step - loss: 0.0047 - accuracy: 0.9991 - precision_2: 0.9991 - recall_2: 0.9992 - val_loss: 0.0604 - val_accuracy: 0.9847 - val_precision_2: 0.9848 - val_recall_2: 0.9845 - lr: 1.0000e-04
# Epoch 14/100
# 320/320 [==============================] - 81s 253ms/step - loss: 0.0025 - accuracy: 0.9999 - precision_2: 0.9999 - recall_2: 0.9999 - val_loss: 0.0619 - val_accuracy: 0.9847 - val_precision_2: 0.9838 - val_recall_2: 0.9857 - lr: 1.0000e-04
# Epoch 15/100
# 320/320 [==============================] - 80s 248ms/step - loss: 0.0020 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9851 - val_precision_2: 0.9860 - val_recall_2: 0.9843 - lr: 1.0000e-04
# Epoch 16/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 320/320 [==============================] - 75s 234ms/step - loss: 0.0017 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9852 - val_precision_2: 0.9857 - val_recall_2: 0.9848 - lr: 1.0000e-04
# Epoch 17/100
# 320/320 [==============================] - 76s 237ms/step - loss: 0.0017 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9848 - val_precision_2: 0.9862 - val_recall_2: 0.9835 - lr: 1.0000e-05
# Epoch 18/100
# 320/320 [==============================] - 80s 249ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9848 - val_precision_2: 0.9862 - val_recall_2: 0.9834 - lr: 1.0000e-05
# Epoch 19/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 320/320 [==============================] - 80s 249ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9849 - val_precision_2: 0.9864 - val_recall_2: 0.9833 - lr: 1.0000e-05
# Epoch 20/100
# 320/320 [==============================] - 80s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9848 - val_precision_2: 0.9866 - val_recall_2: 0.9829 - lr: 1.0000e-06
# Epoch 21/100
# 320/320 [==============================] - 79s 245ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9848 - val_precision_2: 0.9866 - val_recall_2: 0.9829 - lr: 1.0000e-06
# Epoch 22/100
# 320/320 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 320/320 [==============================] - 77s 240ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9848 - val_precision_2: 0.9866 - val_recall_2: 0.9830 - lr: 1.0000e-06
# Epoch 23/100
# 320/320 [==============================] - 79s 244ms/step - loss: 0.0016 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9848 - val_precision_2: 0.9864 - val_recall_2: 0.9831 - lr: 1.0000e-07
# DenseNet Training Time: 1794.99 seconds

# %%
# Measure evaluation time
start_time = time.time()
test_loss, test_accuracy, test_precision, test_recall = DenseNet.evaluate(test_ds)
evaluation_time = time.time() - start_time
print(f"DenseNet Evaluation Time: {evaluation_time:.2f} seconds")

print(f"DenseNet - Test Loss: { test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")
# Out:
# 80/80 [==============================] - 8s 91ms/step - loss: 0.0634 - accuracy: 0.9849 - precision_2: 0.9851 - recall_2: 0.9847
# DenseNet Evaluation Time: 7.73 seconds
# DenseNet - Test Loss: 0.0634, Test Accuracy: 0.9849, Precision: 0.9851, Recall: 0.9847

# %%
# Save model and print size
DenseNet.save("DenseNet64.h5")
DenseNet_model_size = os.path.getsize("DenseNet64.h5")
print(f"DenseNet Model Size: {DenseNet_model_size / (1024 * 1024):.2f} MB")

# Store the metrics and times in the dictionary
stats[DenseNet] = {
    "training_time": training_time,
    "evaluation_time": evaluation_time,
    "test_loss": test_loss,
    "test_accuracy": test_accuracy,
    "test_precision": test_precision,
    "test_recall": test_recall,
    "model_size": DenseNet_model_size / (1024 * 1024),
    "history": DenseNet_history
}
# Out:
# DenseNet Model Size: 83.03 MB

# %%
plot_graph_loss(DenseNet_history)
plot_graph_acc(DenseNet_history)
